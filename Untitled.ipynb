# %%
import dataset
import numpy as np
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
path = "/home/gianscarpe/dev/data/dhp19/time_count_dataset/movements_per_frame/"

# %%
from utils.generate_indexes import save_npy_indexes_and_map
file_paths, train_index, val_index, test_index = save_npy_indexes_and_map(path, split_at=0.8)

# %%
train_index.shape
# Out:
# (58644,)

# %%
d = dataset.get_dataset(file_paths, index=train_index, preload=False, n_channels=1)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
preprocess = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize(256),
            transforms.CenterCrop(256),
            transforms.ToTensor(),
        ])

# %%
loader = DataLoader(d, batch_size=8, shuffle=True, num_workers=0)
it = iter(loader)
first = next(it)

# %%
for f in first[0]:
    img = f.squeeze().numpy()
    plt.figure()
    plt.imshow(img)

# %%
f.squeeze().numpy().shape
# Out:
# (256, 256)
